# %% [markdown]
# ### Analyse de la similarité

# %% [markdown]
# Les mesures de distance jouent un rôle important dans l'apprentissage automatique.
#
# Ils fournissent la base de nombreux algorithmes d'apprentissage automatique populaires et efficaces, tels que les k-NN pour l'apprentissage supervisé et le clustering k-means pour l'apprentissage non supervisé.
#
# Différentes mesures de distance doivent être choisies et utilisées en fonction des types de données.

# %% [markdown]
# #### Distance de Hamming
#
#
# La distance de Hamming calcule la distance entre deux vecteurs binaires, également appelés chaînes binaires ou chaînes de bits en abrégé.
#
# HammingDistance = (somme for i to N abs(v1[i] – v2[i])) / N

# %%
from scipy.spatial.distance import hamming
# Data
row1 = [0, 0, 0, 0, 0, 1]
row2 = [0, 0, 0, 0, 1, 0]
# calcule distance
dist = hamming(row1, row2)
print(dist)
# Out:
# 0.3333333333333333

# %% [markdown]
# #### Distance Euclidienne

# %% [markdown]
# La distance euclidienne calcule la distance entre deux vecteurs de valeurs réelles.
#
#
# EuclideanDistance = racine(somme for i to N (v1[i] – v2[i])^2)
#
# Vous êtes plus susceptible d'utiliser la distance euclidienne lors du calcul de la distance entre deux vecteur de données qui ont des valeur réelles

# %%
from scipy.spatial.distance import euclidean
# data
row1 = [10, 20, 15, 10, 5]
row2 = [12, 24, 18, 8, 7]
# calcul distance
dist = euclidean(row1, row2)
print(dist)
# Out:
# 6.082762530298219

# %% [markdown]
# #### Distance de Manhattan (Taxicab ou City Block Distance)

# %% [markdown]
# La distance de Manhattan, également appelée distance en taxi ou distance en "paté de maison", calcule la distance entre deux vecteurs à valeur réelle.
#
# ManhattanDistance = sum for i to N sum |v1[i] – v2[i]|
#
# Le nom de taxi pour cette mesure fait référence à l'intuition de ce que l'on  calcule: le chemin le plus court qu'un taxi emprunterait entre des pâtés de maisons (coordonnées sur echiquer).

# %%
from scipy.spatial.distance import cityblock
# data
row1 = [10, 20, 15, 10, 5]
row2 = [12, 24, 18, 8, 7]
# calcul distance
dist = cityblock(row1, row2)
print(dist)
# Out:
# 13

# %% [markdown]
# Lors du calcul de la distance entre deux observations, il est possible d'avoir différents types de données par colonne (des valeurs réelles, des valeurs booléennes, des valeurs catégorielles et des valeurs ordinales). Différentes mesures de distance peuvent être nécessaires pour chacune, qui sont additionnées en un seul score de distance.
#
# Les valeurs numériques peuvent avoir des échelles différentes. Cela peut avoir un impact considérable sur le calcul de la mesure de distance et il est souvent recommandé de normaliser les valeurs numériques avant de calculer la mesure de distance.
#
# Une erreur numérique dans les problèmes de régression peut également être considérée comme une distance. Par exemple, l'erreur entre la valeur attendue et la valeur prédite est une mesure de distance unidimensionnelle qui peut être additionnée ou moyennée sur toutes les observations d'un batch pour obtenir une distance totale entre les résultats attendus et prévus.
#
#     Le calcul de l'erreur, comme l'erreur quadratique moyenne ou l'erreur absolue moyenne, peut ressembler à   une mesure de distance standard.

# %% [markdown]
# ####  Veille sur la cosinus similarity
#
#
# - Produit scalaire et notion de colinearité
#
#
# Calculer la colinearité de deux vecteurs en utilisant la valeur du cosinus formée par l'angle de ces vecteurs

# %%
from numpy import dot, linalg

row1 = [10, 20, 15, 10, 5]
row2 = [12, 24, 18, 8, 7]

print(dot(row1, row2))

print(dot(row1, row2)/(linalg.norm(row1)*linalg.norm(row2)))
# Out:
# 985
# 0.9932534635884738

# %% [markdown]
# #### Applications
#
# - Collecter des annonces d'emploi sur indeed
# - Collecter des profils ou CV sur www.lesbonsfreelances.com/ ou un autre site
# - Filtre / Analyse des jeux de données CV et postes
# - Nettoyer intelligement ces documents
# - featurizer votre texte :
# 	- Word count
#    	- Tfidf
# - Evaluez la similarité entre un CV et plusieurs postes (ou inversement) selon différentes metrics:
#     - Cosinus

# %%
import os
import pandas as pd 

import re
from unidecode import unidecode
from nlp_tools import *

path="Postes/"
Poste={}
for nom in os.listdir(path):
    try:
        with open(path+nom,'r') as f:
            Poste[nom]=f.read()
    except:
        continue
        
Postes=pd.DataFrame({"Titre":Poste.keys(),"Content":Poste.values()}).dropna()
Postes.head()
# Out:
# list.remove(x): x not in list
# list.remove(x): x not in list
# list.remove(x): x not in list
# list.remove(x): x not in list
# list.remove(x): x not in list
#                                                Titre  \
# 0  (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nor...
# 1                1_Educateur_de_Jeunes_Enfants_(H_F)
# 2                         1_Travailleur_social_(H_F)
# 3                            2e_Fonde_de_pouvoir_H_F
# 4                                 2_Educateurs_(H_F)
#
#                                              Content
# 0  RattachÃ©(e) au Manager commercial France, vou...
# 1  L'ASSOCIATION JEAN-COTXETrecherche,au sein du ...
# 2  L'ASSOCIATION JEAN-COTXET recherche, au sein d...
# 3   La Caf de Seine-Saint-Denis compte 384 000 al...
# 4  L'ASSOCIATION JEAN-COTXET recherche, au sein d...

# %%
Candidats = pd.read_excel('Candidats.xlsx').dropna()
Candidats.head()
# Out:
#                                                Titre        Nom  \
# 0                             Graphiste Print et Web   sandrat3
# 1             Assistante administrative et juridique  camillel9
# 2  Comptable Clients - optimisation relances - re...   celinef5
# 3               Graphiste & Chargée de communication  violainel
# 4                                  Community manager     carlav
#
#                                                   CV
# 0  Références GRAPHISTE et WEBDESIGNER FREELANCE ...
# 1  Références - Assistante juridique en cabinet c...
# 2  Références De 16/11/2020 à Aujourd’hui  Gérant...
# 3  Références Compétences en Graphisme & en Commu...
# 4  Références C à Vous : Community manager (Live ...

# %% [markdown]
# ## Remove Duplicates

# %%
Postes.drop_duplicates('Content', inplace=True)
Candidats.drop_duplicates('CV', inplace=True)

# %%
print(f"Postes dimension : {Postes.shape}")
print(f"Candidates dimension : {Candidats.shape}")
# Out:
# Postes dimension : (763, 2)
# Candidates dimension : (151, 3)

# %% [markdown]
# ## Nettoyer

# %%
Candidats['CV'].iloc[0]
# Out:
# "Références GRAPHISTE et WEBDESIGNER FREELANCE depuis 2012.  Pour voir mes derniers travaux, merci de consulter mon site www.start-portfolio.com   2015 : ASSISTANTE MARKETING  Au sein d’INNOVZEN, start-up spécialisée dans le secteur du bien-être, seconder la Directrice marketing dans la préparation du Salon Zen à Paris et du CES à Las Vegas. Réaliser les visuels du kit salon, concevoir la plaquette commerciale, les cartes de visite, les flyers. Créer un blog, alimenter les réseaux sociaux et le site web.   2013 : GRAPHISTE  Être force de proposition pour seconder une agence de communication concernant la création du catalogue de la société URBAN-NT, fabrication et pose de mobilier urbain.  Conception de la couverture, mise en page, détourage et retouches avancées de toutes les photos, création des pictos.   Refonte du logo du groupe suivant un cahier des charges précis.   2008-2011 : CHARGÉE DE COMMUNICATION (Lycée DHUODA, GRETA NÎMES, CFA du GARD, CBEN)  Réaliser des maquettes en vue de l’impression d’affiches, flyers, plaquettes commerciales, brochures, PLV, créer des logos ainsi que le site internet du Greta Nîmes Camargue. Prises de vues et retouches photos pour le journal du Lycée.  .  Etudes 2009-2011 : Formation de WEBMASTER et ADMINISTRATEUR RÉSEAUX au CNAM de Montpellier puis obtention du Certificat Professionnel.    2003 : Formation de GRAPHISTE / MAQUETTISTE PAO au Centre IMAGE de Nîmes puis obtention du Certificat Professionnel.   1997-2000 : Cursus de 3 ans à l' École Supérieure des Beaux-Arts de Clermont-Fd puis obtention du Diplôme National d'Arts Plastiques (DNAP) option Art   1993-1996 : Cursus de 3 ans au Lycée Virlogeux de Riom (63) puis obtention du BAC L (Littéraire) options Arts Plastiques et Histoire de l'Art  .  En quelques mots Passionnée, curieuse, créative, rêveuse...je suis...graphiste, illustratrice et webdesigner.   Je vis dans le Sud, mais je peux travailler à distance sur la France entière et au-delà !   Diplômée des Beaux-Arts, je conçois votre communication de manière originale et percutante sur tous supports !   Écoute, patience, créativité, et réactivité sont mes maîtres-mots. Alors travaillons ensemble !"

# %%
cleaner(Candidats['CV'].iloc[0])
# Out:
# 'reference graphiste webdesigner freelance voir travail consulter site www start portfolio com assistant marketing innovzen start up specialise secteur bien seconder directeur marketing preparation salon zen pari vegas realiser visuel kit salon concevoir plaquette commercial carte visiter flyers creer blog alimenter reseau social site web graphiste forcer proposition seconder agencer communication concerner creation cataloguer societe urban nt fabrication poser mobilier urbain conception couverture miser page detourage retoucher avancee photo creation pictos refonte logo grouper cahier charger precis charge communication lycee dhuoda greta nimes cfa gard cben realiser maquette vue impression afficher flyers plaquette commercial brochure plv creer logos site internet greta nimes camargue priser vue retoucher photo journal lycee etudes formation webmaster administrateur reseau cnam montpellier obtention certificat professionnel formation graphiste maquettiste pao centrer imager nimes obtention certificat professionnel cursus an ecole superieur art clermont fd obtention diplome national art plastique dnap option art cursus an lycee virlogeux riom obtention bac litteraire option art plastique histoire art passionne curieux creative reveur graphiste illustrateur webdesigner vis sud mais pouvoir travailler distancer france entier dela diplome art concevoir communication maniere original percutant tout support ecouter patience creativite reactivite maitre travailler ensemble'

# %%
Postes['Content_net']=Postes['Content'].apply(cleaner)
Candidats['CV_net']=Candidats['CV'].apply(cleaner)
Candidats.head()
# Out:
#                                                Titre        Nom  \
# 0                             Graphiste Print et Web   sandrat3
# 1             Assistante administrative et juridique  camillel9
# 2  Comptable Clients - optimisation relances - re...   celinef5
# 3               Graphiste & Chargée de communication  violainel
# 4                                  Community manager     carlav
#
#                                                   CV  \
# 0  Références GRAPHISTE et WEBDESIGNER FREELANCE ...
# 1  Références - Assistante juridique en cabinet c...
# 2  Références De 16/11/2020 à Aujourd’hui  Gérant...
# 3  Références Compétences en Graphisme & en Commu...
# 4  Références C à Vous : Community manager (Live ...
#
#                                               CV_net
# 0  reference graphiste webdesigner freelance voir...
# 1  reference assistant juridique cabinet comptabl...
# 2  reference gerant sarlu recouvrement positif ge...
# 3  reference competence graphisme communication d...
# 4  reference community manager live tweets graphi...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_tfidf = TfidfVectorizer(min_df=3)
vectorizer_tfidf.fit(list(Candidats['CV_net'])+list(Postes['Content_net']))


X_CV = vectorizer_tfidf.transform(Candidats['CV_net'])
X_Postes=vectorizer_tfidf.transform(Postes['Content_net'])

# %%
X_CV_feat=pd.DataFrame(X_CV.toarray(), columns=vectorizer_tfidf.get_feature_names(),index=Candidats['Titre'])
X_CV_feat.head()
# Out:
#                                                     abilit  able  abonnement  \
# Titre
# Graphiste Print et Web                                 0.0   0.0         0.0
# Assistante administrative et juridique                 0.0   0.0         0.0
# Comptable Clients - optimisation relances - rec...     0.0   0.0         0.0
# Graphiste & Chargée de communication                   0.0   0.0         0.0
# Community manager                                      0.0   0.0         0.0
#
#                                                     aborder  aboutir  \
# Titre
# Graphiste Print et Web                                  0.0      0.0
# Assistante administrative et juridique                  0.0      0.0
# Comptable Clients - optimisation relances - rec...      0.0      0.0
# Graphiste & Chargée de communication                    0.0      0.0
# Community manager                                       0.0      0.0
#
#                                                     aboutissement  absence  \
# Titre
# Graphiste Print et Web                                        0.0      0.0
# Assistante administrative et juridique                        0.0      0.0
# Comptable Clients - optimisation relances - rec...            0.0      0.0
# Graphiste & Chargée de communication                          0.0      0.0
# Community manager                                             0.0      0.0
#
#                                                     acad  academy  acc  ...  \
# Titre                                                                   ...
# Graphiste Print et Web                               0.0      0.0  0.0  ...
# Assistante administrative et juridique               0.0      0.0  0.0  ...
# Comptable Clients - optimisation relances - rec...   0.0      0.0  0.0  ...
# Graphiste & Chargée de communication                 0.0      0.0  0.0  ...
# Community manager                                    0.0      0.0  0.0  ...
#
#                                                     york  you  youa  your  \
# Titre
# Graphiste Print et Web                               0.0  0.0   0.0   0.0
# Assistante administrative et juridique               0.0  0.0   0.0   0.0
# Comptable Clients - optimisation relances - rec...   0.0  0.0   0.0   0.0
# Graphiste & Chargée de communication                 0.0  0.0   0.0   0.0
# Community manager                                    0.0  0.0   0.0   0.0
#
#                                                     youtube   yu  yvelines  \
# Titre
# Graphiste Print et Web                                  0.0  0.0       0.0
# Assistante administrative et juridique                  0.0  0.0       0.0
# Comptable Clients - optimisation relances - rec...      0.0  0.0       0.0
# Graphiste & Chargée de communication                    0.0  0.0       0.0
# Community manager                                       0.0  0.0       0.0
#
#                                                     zcspumdhsw       zen  zone
# Titre
# Graphiste Print et Web                                     0.0  0.089351   0.0
# Assistante administrative et juridique                     0.0  0.000000   0.0
# Comptable Clients - optimisation relances - rec...         0.0  0.000000   0.0
# Graphiste & Chargée de communication                       0.0  0.000000   0.0
# Community manager                                          0.0  0.000000   0.0
#
# [5 rows x 4532 columns]

# %%
X_Postes_feat=pd.DataFrame(X_Postes.toarray(), columns=vectorizer_tfidf.get_feature_names(),index=Postes['Titre'])
X_Postes_feat.head()
# Out:
#                                                     abilit  able  abonnement  \
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...     0.0   0.0         0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                    0.0   0.0         0.0
# 1_Travailleur_social_(H_F)                             0.0   0.0         0.0
# 2e_Fonde_de_pouvoir_H_F                                0.0   0.0         0.0
# 2_Educateurs_(H_F)                                     0.0   0.0         0.0
#
#                                                     aborder  aboutir  \
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...      0.0      0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                     0.0      0.0
# 1_Travailleur_social_(H_F)                              0.0      0.0
# 2e_Fonde_de_pouvoir_H_F                                 0.0      0.0
# 2_Educateurs_(H_F)                                      0.0      0.0
#
#                                                     aboutissement  absence  \
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...            0.0      0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                           0.0      0.0
# 1_Travailleur_social_(H_F)                                    0.0      0.0
# 2e_Fonde_de_pouvoir_H_F                                       0.0      0.0
# 2_Educateurs_(H_F)                                            0.0      0.0
#
#                                                     acad  academy  acc  ...  \
# Titre                                                                   ...
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...   0.0      0.0  0.0  ...
# 1_Educateur_de_Jeunes_Enfants_(H_F)                  0.0      0.0  0.0  ...
# 1_Travailleur_social_(H_F)                           0.0      0.0  0.0  ...
# 2e_Fonde_de_pouvoir_H_F                              0.0      0.0  0.0  ...
# 2_Educateurs_(H_F)                                   0.0      0.0  0.0  ...
#
#                                                     york  you  youa  your  \
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...   0.0  0.0   0.0   0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                  0.0  0.0   0.0   0.0
# 1_Travailleur_social_(H_F)                           0.0  0.0   0.0   0.0
# 2e_Fonde_de_pouvoir_H_F                              0.0  0.0   0.0   0.0
# 2_Educateurs_(H_F)                                   0.0  0.0   0.0   0.0
#
#                                                     youtube   yu  yvelines  \
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...      0.0  0.0       0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                     0.0  0.0       0.0
# 1_Travailleur_social_(H_F)                              0.0  0.0       0.0
# 2e_Fonde_de_pouvoir_H_F                                 0.0  0.0       0.0
# 2_Educateurs_(H_F)                                      0.0  0.0       0.0
#
#                                                     zcspumdhsw  zen  zone
# Titre
# (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord...         0.0  0.0   0.0
# 1_Educateur_de_Jeunes_Enfants_(H_F)                        0.0  0.0   0.0
# 1_Travailleur_social_(H_F)                                 0.0  0.0   0.0
# 2e_Fonde_de_pouvoir_H_F                                    0.0  0.0   0.0
# 2_Educateurs_(H_F)                                         0.0  0.0   0.0
#
# [5 rows x 4532 columns]

# %%
import numpy as np

row1 = X_Postes_feat.loc['Comptable_tresorier_H_F']
row2 = X_CV_feat.loc["Comptable Clients - optimisation relances - recouvrement"]

np.dot(row1,row2)/(np.linalg.norm(row1)*np.linalg.norm(row2))
# Out:
# 0.11138293677795506

# %%
from sklearn.metrics.pairwise import cosine_similarity

Resultats=pd.DataFrame(cosine_similarity(X_Postes_feat,X_CV_feat),index=Postes['Titre'],columns=Candidats['Titre'])

# %%
Resultats.T
# Out:
# Titre                                               (H_F)_DELEGUE(E)_COMMERCIAL(E)_COSMETIQUES_Nord-Nord-Ouest  \
# Titre
# Graphiste Print et Web                                                                       0.025176
# Assistante administrative et juridique                                                       0.039550
# Comptable Clients - optimisation relances - rec...                                           0.085272
# Graphiste & Chargée de communication                                                         0.058370
# Community manager                                                                            0.042007
# ...                                                                                               ...
# Consultante Administrative Gestion Finance Val ...                                           0.063436
# Directrice artistique                                                                        0.078973
# Formatrice certifiée Qualiopi/digital & restaur...                                           0.063767
# Graphiste digital 2D et 3D                                                                   0.054463
# Manager QHSE                                                                                 0.086169
#
# Titre                                               1_Educateur_de_Jeunes_Enfants_(H_F)  \
# Titre
# Graphiste Print et Web                                                         0.012973
# Assistante administrative et juridique                                         0.034302
# Comptable Clients - optimisation relances - rec...                             0.018188
# Graphiste & Chargée de communication                                           0.042950
# Community manager                                                              0.030587
# ...                                                                                 ...
# Consultante Administrative Gestion Finance Val ...                             0.025573
# Directrice artistique                                                          0.012627
# Formatrice certifiée Qualiopi/digital & restaur...                             0.033406
# Graphiste digital 2D et 3D                                                     0.011503
# Manager QHSE                                                                   0.015138
#
# Titre                                               1_Travailleur_social_(H_F)  \
# Titre
# Graphiste Print et Web                                                0.023642
# Assistante administrative et juridique                                0.028508
# Comptable Clients - optimisation relances - rec...                    0.024648
# Graphiste & Chargée de communication                                  0.044539
# Community manager                                                     0.044632
# ...                                                                        ...
# Consultante Administrative Gestion Finance Val ...                    0.045014
# Directrice artistique                                                 0.025959
# Formatrice certifiée Qualiopi/digital & restaur...                    0.052973
# Graphiste digital 2D et 3D                                            0.025431
# Manager QHSE                                                          0.021102
#
# Titre                                               2e_Fonde_de_pouvoir_H_F  \
# Titre
# Graphiste Print et Web                                             0.048460
# Assistante administrative et juridique                             0.072611
# Comptable Clients - optimisation relances - rec...                 0.219032
# Graphiste & Chargée de communication                               0.051612
# Community manager                                                  0.049777
# ...                                                                     ...
# Consultante Administrative Gestion Finance Val ...                 0.242394
# Directrice artistique                                              0.038182
# Formatrice certifiée Qualiopi/digital & restaur...                 0.027362
# Graphiste digital 2D et 3D                                         0.034289
# Manager QHSE                                                       0.056159
#
# Titre                                               2_Educateurs_(H_F)  \
# Titre
# Graphiste Print et Web                                        0.020745
# Assistante administrative et juridique                        0.013896
# Comptable Clients - optimisation relances - rec...            0.023337
# Graphiste & Chargée de communication                          0.051039
# Community manager                                             0.027464
# ...                                                                ...
# Consultante Administrative Gestion Finance Val ...            0.043192
# Directrice artistique                                         0.063301
# Formatrice certifiée Qualiopi/digital & restaur...            0.047601
# Graphiste digital 2D et 3D                                    0.022997
# Manager QHSE                                                  0.028596
#
# Titre                                               2_TISF_(H_F)  \
# Titre
# Graphiste Print et Web                                  0.022329
# Assistante administrative et juridique                  0.039310
# Comptable Clients - optimisation relances - rec...      0.017465
# Graphiste & Chargée de communication                    0.043410
# Community manager                                       0.030632
# ...                                                          ...
# Consultante Administrative Gestion Finance Val ...      0.037425
# Directrice artistique                                   0.013527
# Formatrice certifiée Qualiopi/digital & restaur...      0.055760
# Graphiste digital 2D et 3D                              0.033845
# Manager QHSE                                            0.036955
#
# Titre                                               2_Travailleurs_Sociaux_(H_F)  \
# Titre
# Graphiste Print et Web                                                  0.026828
# Assistante administrative et juridique                                  0.027745
# Comptable Clients - optimisation relances - rec...                      0.022275
# Graphiste & Chargée de communication                                    0.044553
# Community manager                                                       0.041049
# ...                                                                          ...
# Consultante Administrative Gestion Finance Val ...                      0.043688
# Directrice artistique                                                   0.028623
# Formatrice certifiée Qualiopi/digital & restaur...                      0.055431
# Graphiste digital 2D et 3D                                              0.025847
# Manager QHSE                                                            0.026323
#
# Titre                                               3_ASSISTANTS_SOCIAUX_(H_F)_AU_SEIN_DU_POLE_MEDECINE  \
# Titre
# Graphiste Print et Web                                                                       0.073224
# Assistante administrative et juridique                                                       0.113637
# Comptable Clients - optimisation relances - rec...                                           0.040759
# Graphiste & Chargée de communication                                                         0.040159
# Community manager                                                                            0.025380
# ...                                                                                               ...
# Consultante Administrative Gestion Finance Val ...                                           0.066096
# Directrice artistique                                                                        0.003800
# Formatrice certifiée Qualiopi/digital & restaur...                                           0.010193
# Graphiste digital 2D et 3D                                                                   0.020594
# Manager QHSE                                                                                 0.037469
#
# Titre                                               3_Ingenieurs_d'affaires_(H_F)  \
# Titre
# Graphiste Print et Web                                                   0.035169
# Assistante administrative et juridique                                   0.060656
# Comptable Clients - optimisation relances - rec...                       0.052187
# Graphiste & Chargée de communication                                     0.047616
# Community manager                                                        0.033478
# ...                                                                           ...
# Consultante Administrative Gestion Finance Val ...                       0.065503
# Directrice artistique                                                    0.024371
# Formatrice certifiée Qualiopi/digital & restaur...                       0.068616
# Graphiste digital 2D et 3D                                               0.063736
# Manager QHSE                                                             0.068385
#
# Titre                                               575270_-_Commercial_-_Paris  \
# Titre
# Graphiste Print et Web                                                 0.041016
# Assistante administrative et juridique                                 0.032792
# Comptable Clients - optimisation relances - rec...                     0.058948
# Graphiste & Chargée de communication                                   0.044852
# Community manager                                                      0.023389
# ...                                                                         ...
# Consultante Administrative Gestion Finance Val ...                     0.038478
# Directrice artistique                                                  0.039116
# Formatrice certifiée Qualiopi/digital & restaur...                     0.047537
# Graphiste digital 2D et 3D                                             0.049574
# Manager QHSE                                                           0.059481
#
# Titre                                               ...  \
# Titre                                               ...
# Graphiste Print et Web                              ...
# Assistante administrative et juridique              ...
# Comptable Clients - optimisation relances - rec...  ...
# Graphiste & Chargée de communication                ...
# Community manager                                   ...
# ...                                                 ...
# Consultante Administrative Gestion Finance Val ...  ...
# Directrice artistique                               ...
# Formatrice certifiée Qualiopi/digital & restaur...  ...
# Graphiste digital 2D et 3D                          ...
# Manager QHSE                                        ...
#
# Titre                                               Verificateur_d'appareils_Extincteurs_H_F  \
# Titre
# Graphiste Print et Web                                                              0.026841
# Assistante administrative et juridique                                              0.041963
# Comptable Clients - optimisation relances - rec...                                  0.038362
# Graphiste & Chargée de communication                                                0.023030
# Community manager                                                                   0.011562
# ...                                                                                      ...
# Consultante Administrative Gestion Finance Val ...                                  0.039249
# Directrice artistique                                                               0.018152
# Formatrice certifiée Qualiopi/digital & restaur...                                  0.025884
# Graphiste digital 2D et 3D                                                          0.012612
# Manager QHSE                                                                        0.037144
#
# Titre                                               Verificateur_Systemes_de_desenfumage_H_F  \
# Titre
# Graphiste Print et Web                                                              0.043110
# Assistante administrative et juridique                                              0.047351
# Comptable Clients - optimisation relances - rec...                                  0.036625
# Graphiste & Chargée de communication                                                0.029929
# Community manager                                                                   0.013146
# ...                                                                                      ...
# Consultante Administrative Gestion Finance Val ...                                  0.035375
# Directrice artistique                                                               0.022028
# Formatrice certifiée Qualiopi/digital & restaur...                                  0.030917
# Graphiste digital 2D et 3D                                                          0.023826
# Manager QHSE                                                                        0.039225
#
# Titre                                               vip_assistant_concierge_luxe_luxury_specialist_paris  \
# Titre
# Graphiste Print et Web                                                                       0.022177
# Assistante administrative et juridique                                                       0.045658
# Comptable Clients - optimisation relances - rec...                                           0.037780
# Graphiste & Chargée de communication                                                         0.035995
# Community manager                                                                            0.020962
# ...                                                                                               ...
# Consultante Administrative Gestion Finance Val ...                                           0.044227
# Directrice artistique                                                                        0.083819
# Formatrice certifiée Qualiopi/digital & restaur...                                           0.035424
# Graphiste digital 2D et 3D                                                                   0.101626
# Manager QHSE                                                                                 0.039985
#
# Titre                                               Visiteur_terrain_H_F  \
# Titre
# Graphiste Print et Web                                          0.024026
# Assistante administrative et juridique                          0.016157
# Comptable Clients - optimisation relances - rec...              0.017637
# Graphiste & Chargée de communication                            0.029547
# Community manager                                               0.025775
# ...                                                                  ...
# Consultante Administrative Gestion Finance Val ...              0.014660
# Directrice artistique                                           0.030531
# Formatrice certifiée Qualiopi/digital & restaur...              0.021254
# Graphiste digital 2D et 3D                                      0.027658
# Manager QHSE                                                    0.009937
#
# Titre                                               Vous_etes_ouvrier_en_demolition,_Wanty_a_besoin_de_vous_pour_ses_chantiers_en_region_parisienne_!  \
# Titre
# Graphiste Print et Web                                                                       0.020778
# Assistante administrative et juridique                                                       0.026736
# Comptable Clients - optimisation relances - rec...                                           0.019209
# Graphiste & Chargée de communication                                                         0.009648
# Community manager                                                                            0.012635
# ...                                                                                               ...
# Consultante Administrative Gestion Finance Val ...                                           0.022493
# Directrice artistique                                                                        0.025583
# Formatrice certifiée Qualiopi/digital & restaur...                                           0.012176
# Graphiste digital 2D et 3D                                                                   0.020616
# Manager QHSE                                                                                 0.022701
#
# Titre                                               Webdesigner___Graphiste_H_F  \
# Titre
# Graphiste Print et Web                                                 0.093549
# Assistante administrative et juridique                                 0.035464
# Comptable Clients - optimisation relances - rec...                     0.031580
# Graphiste & Chargée de communication                                   0.079216
# Community manager                                                      0.091431
# ...                                                                         ...
# Consultante Administrative Gestion Finance Val ...                     0.043261
# Directrice artistique                                                  0.065341
# Formatrice certifiée Qualiopi/digital & restaur...                     0.043449
# Graphiste digital 2D et 3D                                             0.140472
# Manager QHSE                                                           0.033093
#
# Titre                                               WEBMASTER_(H_F)  \
# Titre
# Graphiste Print et Web                                     0.085333
# Assistante administrative et juridique                     0.032687
# Comptable Clients - optimisation relances - rec...         0.039494
# Graphiste & Chargée de communication                       0.031195
# Community manager                                          0.202660
# ...                                                             ...
# Consultante Administrative Gestion Finance Val ...         0.047815
# Directrice artistique                                      0.065691
# Formatrice certifiée Qualiopi/digital & restaur...         0.062246
# Graphiste digital 2D et 3D                                 0.056972
# Manager QHSE                                               0.036014
#
# Titre                                               Webmaster_H_F  \
# Titre
# Graphiste Print et Web                                   0.129141
# Assistante administrative et juridique                   0.054872
# Comptable Clients - optimisation relances - rec...       0.060269
# Graphiste & Chargée de communication                     0.077125
# Community manager                                        0.150139
# ...                                                           ...
# Consultante Administrative Gestion Finance Val ...       0.065080
# Directrice artistique                                    0.076637
# Formatrice certifiée Qualiopi/digital & restaur...       0.063854
# Graphiste digital 2D et 3D                               0.040870
# Manager QHSE                                             0.039384
#
# Titre                                               Welcome_Manager_Barista  \
# Titre
# Graphiste Print et Web                                             0.030498
# Assistante administrative et juridique                             0.035314
# Comptable Clients - optimisation relances - rec...                 0.050094
# Graphiste & Chargée de communication                               0.051938
# Community manager                                                  0.052677
# ...                                                                     ...
# Consultante Administrative Gestion Finance Val ...                 0.049813
# Directrice artistique                                              0.038744
# Formatrice certifiée Qualiopi/digital & restaur...                 0.027945
# Graphiste digital 2D et 3D                                         0.009835
# Manager QHSE                                                       0.032539
#
# Titre                                               Zootechnicien(ne)s_H_F_Rongeurs
# Titre
# Graphiste Print et Web                                                     0.013715
# Assistante administrative et juridique                                     0.030900
# Comptable Clients - optimisation relances - rec...                         0.033965
# Graphiste & Chargée de communication                                       0.020899
# Community manager                                                          0.011590
# ...                                                                             ...
# Consultante Administrative Gestion Finance Val ...                         0.028751
# Directrice artistique                                                      0.009724
# Formatrice certifiée Qualiopi/digital & restaur...                         0.021938
# Graphiste digital 2D et 3D                                                 0.017799
# Manager QHSE                                                               0.018926
#
# [151 rows x 763 columns]

# %%
n_max=5
for i in Resultats.T.index:
    tmp=Resultats.T.loc[i]
    n=0
    while n < n_max :
        try:
            print(i, " VS ",tmp.idxmax(),tmp[tmp.idxmax()])
        except:
            continue
        n=n+1
        tmp[tmp.idxmax()]=0
    print('#################################################')

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=100)
pca.fit(X_CV_feat)
pca_features = pca.transform(X_CV_feat)
print(pca_features.shape)
# Out:
# (151, 100)

# %%
Candidats['CleanCV']=Candidats['CV'].apply(cleaner)
Postes['CleanContent']=Postes['Content'].apply(cleaner)
